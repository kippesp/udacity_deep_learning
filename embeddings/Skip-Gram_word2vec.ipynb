# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:29, 1.07MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

print(len(train_words))
print(len(word_counts.keys()))
# Out:
# 4626522
# 63641

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6654 0.0432 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6024 0.0375 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5048 0.0380 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5931 0.0369 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5239 0.0372 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5521 0.0374 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5746 0.0375 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5852 0.0376 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4930 0.0378 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4457 0.0375 sec/batch
# Nearest to so: wagoner, sheryl, impure, j, refuting, stride, babe, nightshade,
# Nearest to used: taur, contagion, crets, polynomial, reemergence, khosrau, law, burks,
# Nearest to between: pronounces, marriage, oxidative, publicizing, moines, eternal, winslow, bosniaks,
# Nearest to by: quito, topographical, adipose, connections, mysticism, lysergic, pyle, kimono,
# Nearest to use: outlining, kaufman, appointed, gk, sues, alone, mihdhar, chronology,
# Nearest to after: ciphers, selhurst, sharada, malcha, pollution, accorded, powder, mathematics,
# Nearest to seven: televison, jutsu, questions, buboes, majesty, eight, workstations, hearsay,
# Nearest to his: boundary, tobago, apologizing, theologians, purposeful, evangelic, gua, beliefs,
# Nearest to pre: taxes, daybreak, originated, faded, subpages, quartets, sectional, vols,
# Nearest to event: click, cocktail, heckel, functionalities, expels, ligases, stung, proprietors,
# Nearest to alternative: terrace, passages, hashem, wedgwood, amicable, bamar, irresistible, gimps,
# Nearest to recorded: hunchback, afp, bounding, mothman, noll, samantha, garbled, bazin,
# Nearest to file: intrusive, revlon, valiantly, malik, aventis, administrative, entrant, amazona,
# Nearest to grand: indebtedness, noree, mali, emphasise, segmentation, instep, argonne, acuity,
# Nearest to professional: ura, named, lotte, hales, tensile, inadequate, shackleton, dubois,
# Nearest to placed: warrant, chrismation, career, guerre, workmanship, fugues, cogency, princes,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4791 0.0391 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3576 0.0373 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3166 0.0376 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2406 0.0374 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1910 0.0376 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1832 0.0380 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1128 0.0379 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0604 0.0371 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0160 0.0373 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9857 0.0374 sec/batch
# Nearest to so: wagoner, j, sheryl, impure, refuting, stride, experiments, vessels,
# Nearest to used: law, polynomial, reemergence, khosrau, freedoms, crets, fees, taur,
# Nearest to between: marriage, eternal, publicizing, pronounces, moines, oxidative, protect, chaos,
# Nearest to by: topographical, quito, roll, connections, mysticism, adipose, thought, part,
# Nearest to use: outlining, alone, appointed, though, kaufman, animals, chronology, microsoft,
# Nearest to after: mathematics, ciphers, accorded, pollution, deal, powder, selhurst, issues,
# Nearest to seven: according, president, did, workstations, felt, worldwide, questions, televison,
# Nearest to his: boundary, tobago, column, beliefs, theologians, reorganised, granada, anglo,
# Nearest to pre: taxes, originated, heard, vols, faded, started, only, french,
# Nearest to event: click, cocktail, moment, heckel, servant, functionalities, sets, appalachian,
# Nearest to alternative: passages, amicable, hashem, terrace, bamar, gibbon, coalitions, irresistible,
# Nearest to recorded: hunchback, samantha, bounding, noll, bonin, engine, mothman, afp,
# Nearest to file: intrusive, administrative, revlon, valiantly, known, aventis, these, resides,
# Nearest to grand: indebtedness, segmentation, mali, noree, emphasise, instep, exercised, argonne,
# Nearest to professional: named, inadequate, rate, tour, shackleton, tensile, isk, ura,
# Nearest to placed: warrant, access, career, function, guerre, chrismation, succession, nara,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9677 0.0387 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9153 0.0379 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8765 0.0376 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8844 0.0378 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8283 0.0371 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8166 0.0374 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8100 0.0377 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8108 0.0376 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7952 0.0376 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7906 0.0372 sec/batch
# Nearest to so: wagoner, sheryl, impure, j, refuting, transferable, babe, stride,
# Nearest to used: polynomial, law, reemergence, contagion, crets, taur, fees, freedoms,
# Nearest to between: eternal, marriage, publicizing, pronounces, moines, winslow, oxidative, chaos,
# Nearest to by: quito, mysticism, topographical, moderate, roll, authorities, salary, offers,
# Nearest to use: outlining, chronology, appointed, microsoft, alone, kaufman, endings, though,
# Nearest to after: pollution, accorded, ciphers, mathematics, deal, selhurst, fears, powder,
# Nearest to seven: president, eight, mood, notoriously, majesty, bulletin, workstations, scream,
# Nearest to his: boundary, tobago, beliefs, theologians, anglo, tactical, die, reorganised,
# Nearest to pre: taxes, originated, faded, heard, started, vols, only, townhouse,
# Nearest to event: click, moment, cocktail, functionalities, heckel, discoverer, ligases, leech,
# Nearest to alternative: passages, amicable, terrace, hashem, coalitions, bamar, apostles, irresistible,
# Nearest to recorded: hunchback, samantha, bounding, engine, noll, bonin, analyse, afp,
# Nearest to file: intrusive, valiantly, administrative, revlon, known, resides, relativism, these,
# Nearest to grand: segmentation, indebtedness, mali, emphasise, exercised, noree, leslie, bow,
# Nearest to professional: named, inadequate, tour, shackleton, purchased, phones, ura, nancy,
# Nearest to placed: warrant, career, access, chrismation, function, succession, guerre, fugues,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7712 0.0390 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7660 0.0372 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7369 0.0372 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7240 0.0377 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7234 0.0379 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7229 0.0375 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6704 0.0375 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7291 0.0376 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7087 0.0367 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6668 0.0380 sec/batch
# Nearest to so: wagoner, impure, refuting, sheryl, transferable, stride, egoism, chlamydia,
# Nearest to used: polynomial, contagion, reemergence, law, crets, taur, null, khosrau,
# Nearest to between: eternal, pronounces, marriage, moines, publicizing, winslow, chaos, forested,
# Nearest to by: mysticism, quito, topographical, kimono, moderate, henrietta, sax, primate,
# Nearest to use: outlining, chronology, activism, microsoft, commences, mihdhar, endings, sues,
# Nearest to after: accorded, combatants, selhurst, seeing, pollution, reptilian, fears, potomac,
# Nearest to seven: eight, president, zero, four, afc, majesty, upmarket, bulletin,
# Nearest to his: boundary, beliefs, theologians, tobago, anglo, avery, druids, embarrassing,
# Nearest to pre: originated, taxes, faded, started, megaliths, tiber, townhouse, aging,
# Nearest to event: click, moment, functionalities, expansionist, cocktail, expels, proprietors, discoverer,
# Nearest to alternative: passages, amicable, terrace, hashem, irresistible, coalitions, wedgwood, apostles,
# Nearest to recorded: hunchback, samantha, bounding, afp, noll, bonin, analyse, neoliberalism,
# Nearest to file: intrusive, revlon, valiantly, relativism, entrant, bridgetown, known, resides,
# Nearest to grand: segmentation, indebtedness, mali, emphasise, leslie, lodgings, bow, immanuel,
# Nearest to professional: inadequate, named, shackleton, phones, ura, tour, hales, stabs,
# Nearest to placed: warrant, chrismation, access, workmanship, career, fugues, nara, guerre,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6693 0.0385 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6528 0.0377 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6232 0.0377 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6373 0.0374 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6355 0.0375 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6261 0.0375 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5875 0.0283 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5483 0.0380 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5144 0.0376 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5100 0.0375 sec/batch
# Nearest to so: wagoner, refuting, impure, transferable, sheryl, stride, abstract, biased,
# Nearest to used: polynomial, contagion, law, null, reemergence, crets, stricter, lynx,
# Nearest to between: eternal, moines, pronounces, publicizing, chaos, winslow, marriage, merritt,
# Nearest to by: quito, mysticism, kimono, respite, moderate, topographical, henrietta, place,
# Nearest to use: outlining, microsoft, functions, though, chronology, activism, sues, mihdhar,
# Nearest to after: accorded, schiller, combatants, potomac, selhurst, fears, reptilian, ludovico,
# Nearest to seven: eight, president, zero, afc, four, three, moritz, swimmer,
# Nearest to his: druids, anglo, alfred, theologians, reorganised, beliefs, joined, nikolaus,
# Nearest to pre: originated, taxes, faded, megaliths, sectional, started, strangely, tiber,
# Nearest to event: click, moment, ligases, functionalities, heckel, expels, expansionist, stung,
# Nearest to alternative: passages, amicable, irresistible, hashem, terrace, chokes, bamar, wedgwood,
# Nearest to recorded: hunchback, samantha, bounding, afp, graded, mothman, noll, analyse,
# Nearest to file: intrusive, revlon, entrant, valiantly, relativism, brainwashed, bridgetown, known,
# Nearest to grand: segmentation, indebtedness, mali, emphasise, leslie, vouchers, bow, lodgings,
# Nearest to professional: named, shackleton, inadequate, ura, diffracted, phones, hales, roeg,
# Nearest to placed: warrant, chrismation, workmanship, career, access, fugues, alluvium, guerre,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4897 0.0389 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4878 0.0374 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4924 0.0375 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5360 0.0375 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5162 0.0379 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4626 0.0370 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4346 0.0381 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4044 0.0367 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4298 0.0376 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4253 0.0374 sec/batch
# Nearest to so: wagoner, impure, refuting, stride, sheryl, abstract, biased, transferable,
# Nearest to used: polynomial, contagion, null, lynx, law, crets, reemergence, storage,
# Nearest to between: moines, eternal, pronounces, publicizing, forested, winslow, culpability, merritt,
# Nearest to by: kimono, quito, henrietta, mysticism, topographical, primate, respite, connections,
# Nearest to use: outlining, programs, microsoft, though, endings, mihdhar, source, activism,
# Nearest to after: potomac, schiller, accorded, combatants, selhurst, ludovico, fears, forestalled,
# Nearest to seven: eight, zero, afc, president, upmarket, four, televison, amc,
# Nearest to his: he, druids, theologians, son, beliefs, anglo, joined, nikolaus,
# Nearest to pre: strangely, megaliths, originated, taxes, subpages, tiber, sectional, faded,
# Nearest to event: click, ligases, heckel, functionalities, moment, expansionist, aztec, expels,
# Nearest to alternative: amicable, irresistible, hashem, terrace, passages, chokes, premises, wedgwood,
# Nearest to recorded: hunchback, bounding, graded, samantha, afp, neoliberalism, mothman, yesterday,
# Nearest to file: intrusive, revlon, relativism, valiantly, entrant, software, brainwashed, raptor,
# Nearest to grand: segmentation, indebtedness, mali, emphasise, leslie, vouchers, delgado, lodgings,
# Nearest to professional: named, shackleton, hales, stabs, diffracted, inadequate, ura, roeg,
# Nearest to placed: warrant, workmanship, chrismation, career, guerre, schists, alluvium, fugues,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4248 0.0378 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4202 0.0376 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4260 0.0370 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3894 0.0377 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4114 0.0376 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4565 0.0375 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3916 0.0372 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3784 0.0375 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4147 0.0374 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3890 0.0378 sec/batch
# Nearest to so: wagoner, impure, refuting, stride, biased, transferable, abstract, glide,
# Nearest to used: polynomial, contagion, null, lynx, crets, law, khosrau, taur,
# Nearest to between: moines, forested, eternal, publicizing, pronounces, chaos, guaranteed, flavorings,
# Nearest to by: topographical, quito, henrietta, primate, mysticism, kimono, connections, disagrees,
# Nearest to use: outlining, microsoft, programs, endings, specified, though, implementations, source,
# Nearest to after: schiller, selhurst, accorded, potomac, combatants, forestalled, reptilian, censor,
# Nearest to seven: eight, zero, afc, four, upmarket, three, amc, president,
# Nearest to his: he, druids, theologians, son, beliefs, beheaded, nikolaus, indulgence,
# Nearest to pre: strangely, megaliths, originated, subpages, tiber, taxes, faded, daybreak,
# Nearest to event: click, ligases, heckel, functionalities, moment, aztec, expels, cocktail,
# Nearest to alternative: amicable, irresistible, hashem, passages, equivalent, chokes, premises, terrace,
# Nearest to recorded: hunchback, homeward, neoliberalism, bounding, yesterday, riley, graded, afp,
# Nearest to file: intrusive, software, revlon, formatting, entrant, valiantly, programming, bridgetown,
# Nearest to grand: segmentation, mali, indebtedness, leslie, emphasise, vouchers, lodgings, venlafaxine,
# Nearest to professional: named, shackleton, stabs, hales, diffracted, ura, nancy, roeg,
# Nearest to placed: warrant, career, workmanship, chrismation, harvested, fugues, schists, onomatopoeic,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3928 0.0388 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4100 0.0376 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3697 0.0378 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3645 0.0373 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3774 0.0379 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3516 0.0378 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4016 0.0375 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3983 0.0380 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3125 0.0379 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3178 0.0372 sec/batch
# Nearest to so: wagoner, impure, refuting, glide, abstract, stride, subtraction, biased,
# Nearest to used: contagion, null, polynomial, lynx, taur, redundantly, sported, crets,
# Nearest to between: moines, forested, guaranteed, chaos, eternal, coloureds, duality, relies,
# Nearest to by: connections, topographical, denominators, kingdom, hierarchal, henrietta, quito, obligations,
# Nearest to use: outlining, programs, endings, microsoft, though, specified, plywood, trusts,
# Nearest to after: schiller, accorded, potomac, selhurst, combatants, reptilian, forestalled, defeat,
# Nearest to seven: eight, zero, four, three, upmarket, afc, five, president,
# Nearest to his: he, son, druids, theologians, maesa, beheaded, anglo, indulgence,
# Nearest to pre: strangely, megaliths, originated, tiber, subpages, daybreak, sectional, faded,
# Nearest to event: ligases, click, heckel, functionalities, aztec, moment, cocktail, hearn,
# Nearest to alternative: hashem, amicable, chokes, irresistible, equivalent, terrace, wedgwood, bamar,
# Nearest to recorded: hunchback, homeward, bounding, samantha, neoliberalism, riley, graded, yesterday,
# Nearest to file: intrusive, software, formatting, revlon, database, programming, entrant, haskell,
# Nearest to grand: segmentation, indebtedness, mali, emphasise, leslie, delgado, lodgings, trygve,
# Nearest to professional: shackleton, named, stabs, diffracted, ura, hales, nancy, lotte,
# Nearest to placed: warrant, career, workmanship, chrismation, fugues, harvested, schists, guerre,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3604 0.0384 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3160 0.0370 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.4064 0.0380 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3906 0.0374 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4118 0.0371 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2875 0.0374 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3294 0.0371 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3468 0.0370 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2194 0.0377 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2918 0.0376 sec/batch
# Nearest to so: wagoner, refuting, impure, glide, stride, abstract, biased, chlamydia,
# Nearest to used: contagion, polynomial, lynx, null, sported, redundantly, fooled, additive,
# Nearest to between: moines, forested, guaranteed, culpability, coloureds, eternal, pronounces, relies,
# Nearest to by: denominators, connections, hierarchal, topographical, quoting, quito, euston, disagrees,
# Nearest to use: outlining, endings, repeater, programs, microsoft, plywood, specified, though,
# Nearest to after: schiller, combatants, selhurst, accorded, potomac, forestalled, masques, reptilian,
# Nearest to seven: eight, zero, four, three, five, six, two, president,
# Nearest to his: he, druids, karlsson, beloved, nikolaus, beheaded, grandfather, maesa,
# Nearest to pre: strangely, tiber, originated, megaliths, daybreak, corrupts, subpages, sectional,
# Nearest to event: ligases, click, heckel, functionalities, moment, aztec, cocktail, stung,
# Nearest to alternative: hashem, amicable, chokes, irresistible, terrace, equivalent, alexanderplatz, gimps,
# Nearest to recorded: hunchback, homeward, samantha, riley, bounding, graded, bazin, singin,
# Nearest to file: intrusive, formatting, software, revlon, entrant, database, bridgetown, morissette,
# Nearest to grand: mali, indebtedness, segmentation, trygve, venlafaxine, delgado, emphasise, leslie,
# Nearest to professional: shackleton, named, stabs, diffracted, nancy, ura, lotte, hales,
# Nearest to placed: warrant, workmanship, career, harvested, schists, fugues, chrismation, guerre,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3084 0.0390 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2895 0.0373 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3517 0.0184 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2534 0.0376 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2525 0.0375 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2349 0.0375 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1938 0.0380 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2153 0.0374 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2239 0.0376 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2155 0.0379 sec/batch
# Nearest to so: wagoner, impure, refuting, glide, try, biased, stride, start,
# Nearest to used: lynx, contagion, null, redundantly, polynomial, sported, khosrau, fooled,
# Nearest to between: moines, forested, guaranteed, coloureds, culpability, flavorings, pronounces, eternal,
# Nearest to by: quito, denominators, connections, euston, topographical, kingdom, hierarchal, disagrees,
# Nearest to use: outlining, repeater, endings, plywood, programs, microsoft, though, qualitative,
# Nearest to after: schiller, selhurst, potomac, combatants, amply, accorded, forestalled, ludovico,
# Nearest to seven: zero, eight, four, three, five, two, upmarket, annexes,
# Nearest to his: he, beloved, beheaded, grandfather, mountbatten, druids, endemol, karlsson,
# Nearest to pre: strangely, megaliths, originated, tiber, daybreak, subpages, corrupts, sectional,
# Nearest to event: ligases, click, heckel, functionalities, aztec, moment, cocktail, hearn,
# Nearest to alternative: hashem, amicable, chokes, terrace, alexanderplatz, irresistible, ways, ekaterina,
# Nearest to recorded: homeward, hunchback, samantha, riley, neoliberalism, bounding, graded, bacall,
# Nearest to file: intrusive, formatting, revlon, entrant, software, database, relativism, morissette,
# Nearest to grand: indebtedness, mali, segmentation, emphasise, marred, trygve, delgado, vouchers,
# Nearest to professional: shackleton, named, stabs, diffracted, hales, ura, rookies, roeg,
# Nearest to placed: warrant, workmanship, career, schists, guerre, chrismation, fugues, harvested,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2554 0.0391 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2065 0.0376 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2111 0.0373 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1144 0.0377 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1663 0.0379 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1514 0.0375 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1536 0.0379 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1863 0.0372 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2080 0.0374 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1860 0.0376 sec/batch
# Nearest to so: wagoner, impure, refuting, try, glide, start, stride, biased,
# Nearest to used: contagion, polynomial, zirconia, lynx, redundantly, null, sported, use,
# Nearest to between: forested, moines, guaranteed, coloureds, flavorings, culpability, relies, waived,
# Nearest to by: denominators, connections, quito, disagrees, topographical, june, in, signal,
# Nearest to use: outlining, endings, repeater, used, though, plywood, trusts, microsoft,
# Nearest to after: selhurst, schiller, priced, potomac, amply, forestalled, accorded, combatants,
# Nearest to seven: zero, eight, four, three, five, two, upmarket, afc,
# Nearest to his: he, beloved, beheaded, mountbatten, karlsson, endemol, druids, grandfather,
# Nearest to pre: strangely, megaliths, originated, tiber, daybreak, corrupts, sectional, subpages,
# Nearest to event: ligases, click, functionalities, heckel, christmas, aztec, moment, hearn,
# Nearest to alternative: hashem, amicable, terrace, chokes, irresistible, ways, alexanderplatz, ekaterina,
# Nearest to recorded: hunchback, homeward, bounding, samantha, yesterday, riley, neoliberalism, bacall,
# Nearest to file: formatting, intrusive, revlon, entrant, software, relativism, valiantly, corundum,
# Nearest to grand: indebtedness, mali, emphasise, segmentation, battalions, trygve, marred, delgado,
# Nearest to professional: shackleton, named, stabs, diffracted, rookies, inadequate, hales, ura,
# Nearest to placed: workmanship, warrant, harvested, schists, fugues, ilife, career, concealed,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1849 0.0387 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2150 0.0377 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1780 0.0369 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1589 0.0377 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1973 0.0372 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1500 0.0370 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2082 0.0379 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1751 0.0377 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1363 0.0371 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1777 0.0379 sec/batch
# Nearest to so: wagoner, impure, refuting, favouring, try, seniors, glide, biased,
# Nearest to used: contagion, lynx, sported, zirconia, redundantly, watling, midair, considered,
# Nearest to between: moines, forested, guaranteed, coloureds, culpability, relies, flavorings, waived,
# Nearest to by: denominators, connections, hierarchal, in, june, of, signal, akad,
# Nearest to use: endings, outlining, repeater, microsoft, though, plywood, used, specified,
# Nearest to after: selhurst, schiller, potomac, priced, masques, accorded, forestalled, combatants,
# Nearest to seven: zero, eight, four, three, five, two, six, upmarket,
# Nearest to his: he, mountbatten, beloved, beheaded, endemol, karlsson, grandfather, druids,
# Nearest to pre: megaliths, strangely, originated, tiber, daybreak, corrupts, sectional, subpages,
# Nearest to event: ligases, click, functionalities, heckel, moment, hearn, aztec, scat,
# Nearest to alternative: hashem, ways, amicable, chokes, terrace, irresistible, alexanderplatz, endosymbiosis,
# Nearest to recorded: homeward, hunchback, samantha, bounding, yesterday, bacall, singin, aldiss,
# Nearest to file: formatting, intrusive, software, database, revlon, entrant, relativism, productofpowers,
# Nearest to grand: indebtedness, segmentation, emphasise, mali, trygve, venlafaxine, marred, delgado,
# Nearest to professional: shackleton, stabs, named, rookies, inadequate, diffracted, ura, doolittle,
# Nearest to placed: warrant, workmanship, fugues, career, concealed, harvested, onomatopoeic, schists,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2119 0.0383 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1689 0.0372 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1997 0.0373 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1705 0.0372 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1721 0.0376 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1219 0.0376 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.2208 0.0379 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1384 0.0376 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1920 0.0377 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1924 0.0379 sec/batch
# Nearest to so: wagoner, refuting, impure, favouring, try, seniors, start, picket,
# Nearest to used: sported, contagion, lynx, midair, keyboard, zirconia, use, disproved,
# Nearest to between: moines, forested, coloureds, guaranteed, culpability, eternal, rearward, chaos,
# Nearest to by: denominators, june, in, of, connections, became, quito, consignee,
# Nearest to use: endings, outlining, repeater, used, kaufman, though, reserved, plywood,
# Nearest to after: selhurst, potomac, schiller, resulted, combatants, defeat, alsace, masques,
# Nearest to seven: eight, zero, four, five, three, two, six, bibliographer,
# Nearest to his: he, mountbatten, beloved, awarded, maesa, beheaded, karlsson, endemol,
# Nearest to pre: strangely, originated, megaliths, daybreak, tiber, corrupts, sectional, orford,
# Nearest to event: ligases, click, functionalities, heckel, aztec, christmas, moment, scat,
# Nearest to alternative: hashem, terrace, ways, amicable, chokes, irresistible, endosymbiosis, alexanderplatz,
# Nearest to recorded: homeward, hunchback, samantha, bacall, singin, yesterday, riley, bounding,
# Nearest to file: formatting, intrusive, software, database, revlon, entrant, relativism, directories,
# Nearest to grand: indebtedness, segmentation, emphasise, mali, trygve, marred, venlafaxine, delgado,
# Nearest to professional: shackleton, stabs, rookies, named, diffracted, inadequate, hales, ura,
# Nearest to placed: warrant, workmanship, fugues, guerre, succession, concealed, schists, career,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2245 0.0387 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1163 0.0375 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1506 0.0374 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1519 0.0375 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0286 0.0377 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1313 0.0377 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1403 0.0374 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1478 0.0374 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1630 0.0084 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1047 0.0376 sec/batch
# Nearest to so: wagoner, impure, refuting, try, start, calculi, picket, seniors,
# Nearest to used: use, sported, contagion, zirconia, disproved, keyboard, midair, redundantly,
# Nearest to between: moines, forested, coloureds, guaranteed, carolla, culpability, chaos, uncollected,
# Nearest to by: in, denominators, of, june, connections, signal, became, the,
# Nearest to use: endings, used, outlining, repeater, though, gk, plywood, martensite,
# Nearest to after: selhurst, resulted, schiller, combatants, potomac, afp, defeat, cringely,
# Nearest to seven: zero, eight, four, five, two, three, six, hdi,
# Nearest to his: he, mountbatten, awarded, grandfather, karlsson, beheaded, endemol, maesa,
# Nearest to pre: megaliths, originated, strangely, tiber, daybreak, corrupts, preclear, monolithic,
# Nearest to event: ligases, click, moment, heckel, functionalities, christmas, hearn, aztec,
# Nearest to alternative: ways, hashem, terrace, chokes, endosymbiosis, alexanderplatz, ekaterina, amicable,
# Nearest to recorded: homeward, hunchback, samantha, singin, bacall, bounding, misty, etna,
# Nearest to file: formatting, intrusive, software, revlon, relativism, database, entrant, administrative,
# Nearest to grand: indebtedness, mali, trygve, emphasise, marred, segmentation, venlafaxine, delgado,
# Nearest to professional: shackleton, rookies, stabs, diffracted, arnaud, named, inadequate, hales,
# Nearest to placed: warrant, workmanship, fugues, succession, concealed, guerre, schists, ilife,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1118 0.0386 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0824 0.0374 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0878 0.0377 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0481 0.0376 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0972 0.0374 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0435 0.0381 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1057 0.0378 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0869 0.0371 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1134 0.0377 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0348 0.0377 sec/batch
# Nearest to so: wagoner, impure, refuting, try, start, picket, favouring, babe,
# Nearest to used: use, sported, contagion, considered, midair, lynx, zirconia, redundantly,
# Nearest to between: forested, moines, guaranteed, coloureds, rearward, culpability, eternal, strongest,
# Nearest to by: in, of, denominators, the, june, connections, became, signal,
# Nearest to use: endings, repeater, used, outlining, though, martensite, reserved, evade,
# Nearest to after: selhurst, potomac, resulted, schiller, returned, priced, backwards, afp,
# Nearest to seven: zero, eight, four, three, five, two, six, amc,
# Nearest to his: he, mountbatten, beheaded, beloved, grandfather, awarded, karlsson, maesa,
# Nearest to pre: megaliths, originated, strangely, tiber, daybreak, preclear, corrupts, monolithic,
# Nearest to event: ligases, click, heckel, functionalities, drummond, christmas, moment, hearn,
# Nearest to alternative: ways, hashem, chokes, alexanderplatz, terrace, amicable, endosymbiosis, amuck,
# Nearest to recorded: homeward, hunchback, singin, samantha, bacall, bounding, breakthrough, yesterday,
# Nearest to file: formatting, intrusive, revlon, software, entrant, relativism, administrative, morissette,
# Nearest to grand: indebtedness, emphasise, segmentation, mali, trygve, marred, venlafaxine, delgado,
# Nearest to professional: shackleton, rookies, stabs, diffracted, named, arnaud, outfielder, cripple,
# Nearest to placed: warrant, fugues, succession, workmanship, concealed, unguarded, guerre, hicks,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0067 0.0386 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0330 0.0375 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0260 0.0374 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0679 0.0372 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0677 0.0369 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0502 0.0370 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0609 0.0369 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1236 0.0375 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0534 0.0377 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0478 0.0372 sec/batch
# Nearest to so: wagoner, impure, refuting, favouring, try, start, calculi, glide,
# Nearest to used: use, considered, zirconia, midair, sported, redundantly, contagion, disproved,
# Nearest to between: forested, moines, guaranteed, coloureds, rearward, level, culpability, uncollected,
# Nearest to by: in, of, denominators, the, as, various, dedicate, june,
# Nearest to use: used, endings, repeater, outlining, though, source, reserved, kaufman,
# Nearest to after: selhurst, backwards, potomac, pressurised, afp, resulted, nernst, mathematics,
# Nearest to seven: zero, eight, four, three, five, two, six, hdi,
# Nearest to his: he, mountbatten, grandfather, beloved, beheaded, awarded, endemol, maesa,
# Nearest to pre: megaliths, originated, strangely, monolithic, daybreak, tiber, preclear, constructs,
# Nearest to event: ligases, click, functionalities, moment, heckel, extremely, amperes, aztec,
# Nearest to alternative: hashem, ways, endosymbiosis, chokes, amuck, amicable, alexanderplatz, blurs,
# Nearest to recorded: homeward, hunchback, bounding, bacall, samantha, singin, misty, yesterday,
# Nearest to file: formatting, intrusive, revlon, entrant, wavelets, software, administrative, corundum,
# Nearest to grand: indebtedness, emphasise, segmentation, mali, trygve, marred, venlafaxine, hogmanay,
# Nearest to professional: rookies, shackleton, stabs, diffracted, named, inadequate, cripple, arnaud,
# Nearest to placed: warrant, fugues, workmanship, concealed, succession, ilife, hicks, unguarded,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0545 0.0386 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0863 0.0372 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0914 0.0372 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0466 0.0368 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0649 0.0371 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0788 0.0376 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0654 0.0378 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0712 0.0376 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0623 0.0371 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0739 0.0375 sec/batch
# Nearest to so: wagoner, refuting, impure, favouring, start, obtained, try, picket,
# Nearest to used: use, zirconia, midair, considered, kana, sported, disproved, contagion,
# Nearest to between: forested, moines, guaranteed, coloureds, uncollected, culpability, rearward, level,
# Nearest to by: in, of, the, became, june, denominators, as, consignee,
# Nearest to use: used, endings, outlining, though, repeater, tippi, kaufman, reserved,
# Nearest to after: selhurst, potomac, resulted, returned, reestablished, staging, schiller, place,
# Nearest to seven: zero, eight, four, three, five, two, six, hdi,
# Nearest to his: he, beheaded, mountbatten, grandfather, endemol, awarded, maesa, nikolaus,
# Nearest to pre: megaliths, originated, strangely, monolithic, tiber, daybreak, started, preclear,
# Nearest to event: ligases, click, functionalities, moment, heckel, scat, amperes, aztec,
# Nearest to alternative: endosymbiosis, hashem, ways, chokes, amuck, alexanderplatz, amicable, terrace,
# Nearest to recorded: homeward, hunchback, bacall, samantha, bounding, yesterday, singin, misty,
# Nearest to file: formatting, intrusive, revlon, files, software, entrant, wavelets, directories,
# Nearest to grand: indebtedness, emphasise, segmentation, mali, marred, trygve, venlafaxine, hogmanay,
# Nearest to professional: rookies, shackleton, stabs, diffracted, inadequate, ura, arnaud, named,
# Nearest to placed: warrant, unguarded, concealed, fugues, workmanship, succession, roof, sit,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0564 0.0391 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0267 0.0373 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0510 0.0374 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0687 0.0375 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0783 0.0379 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1256 0.0373 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1104 0.0378 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0170 0.0377 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0505 0.0372 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0502 0.0370 sec/batch
# Nearest to so: wagoner, refuting, impure, obtained, picket, calculi, favouring, start,
# Nearest to used: use, sported, zirconia, midair, considered, kana, disproved, electrolytic,
# Nearest to between: forested, moines, guaranteed, culpability, coloureds, carolla, uncollected, level,
# Nearest to by: in, of, denominators, june, became, signal, the, as,
# Nearest to use: used, endings, repeater, outlining, though, reserved, tippi, gk,
# Nearest to after: resulted, selhurst, potomac, returned, afp, place, before, schiller,
# Nearest to seven: zero, eight, four, three, five, two, six, hdi,
# Nearest to his: he, grandfather, awarded, maesa, endemol, beheaded, nikolaus, mountbatten,
# Nearest to pre: megaliths, originated, strangely, daybreak, monolithic, preclear, started, tiber,
# Nearest to event: ligases, click, moment, scat, functionalities, heckel, aztec, hearn,
# Nearest to alternative: endosymbiosis, hashem, ways, chokes, alexanderplatz, amuck, houteff, totschlag,
# Nearest to recorded: homeward, hunchback, bacall, samantha, singin, misty, yesterday, riff,
# Nearest to file: formatting, intrusive, files, revlon, software, entrant, itunes, directories,
# Nearest to grand: indebtedness, emphasise, segmentation, mali, marred, trygve, venlafaxine, delgado,
# Nearest to professional: rookies, shackleton, stabs, arnaud, diffracted, hales, kibo, cripple,
# Nearest to placed: warrant, fugues, succession, unguarded, concealed, workmanship, hicks, sit,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9746 0.0385 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0285 0.0373 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0569 0.0372 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0177 0.0376 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0818 0.0376 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0406 0.0360 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0053 0.0373 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9977 0.0379 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0537 0.0376 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9590 0.0374 sec/batch
# Nearest to so: wagoner, impure, picket, refuting, obtained, try, calculi, seniors,
# Nearest to used: use, considered, zirconia, midair, sported, disproved, keyboard, kana,
# Nearest to between: forested, carolla, guaranteed, moines, uncollected, pubic, coloureds, level,
# Nearest to by: in, of, the, denominators, as, dedicate, june, fromme,
# Nearest to use: used, endings, repeater, martensite, cohesion, though, outlining, mdma,
# Nearest to after: selhurst, resulted, potomac, returned, afp, before, danilo, to,
# Nearest to seven: zero, eight, three, four, five, two, six, one,
# Nearest to his: he, grandfather, beheaded, maesa, awarded, was, mountbatten, endemol,
# Nearest to pre: megaliths, originated, strangely, monolithic, daybreak, preclear, started, tiber,
# Nearest to event: ligases, click, moment, scat, heckel, hearn, functionalities, christmas,
# Nearest to alternative: endosymbiosis, ways, hashem, chokes, amuck, invocation, totschlag, alexanderplatz,
# Nearest to recorded: homeward, hunchback, bacall, samantha, misty, singin, riff, nu,
# Nearest to file: formatting, intrusive, files, revlon, itunes, mp, format, wavelets,
# Nearest to grand: indebtedness, emphasise, segmentation, marred, mali, trygve, venlafaxine, hogmanay,
# Nearest to professional: rookies, shackleton, stabs, arnaud, kibo, diffracted, hales, cantrell,
# Nearest to placed: warrant, succession, hicks, fugues, unguarded, concealed, roof, ilife,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9972 0.0385 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9375 0.0376 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0302 0.0378 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0198 0.0380 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0269 0.0372 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0039 0.0374 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8877 0.0375 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9591 0.0374 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9159 0.0363 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9961 0.0370 sec/batch
# Nearest to so: wagoner, impure, refuting, obtained, picket, try, start, glide,
# Nearest to used: use, zirconia, considered, sported, midair, electrolytic, keyboard, porosity,
# Nearest to between: forested, level, and, coloureds, moines, pubic, guaranteed, uncollected,
# Nearest to by: in, of, the, as, denominators, dedicate, and, june,
# Nearest to use: used, repeater, endings, though, cohesion, outlining, deducted, martensite,
# Nearest to after: selhurst, resulted, before, potomac, afp, returned, backwards, to,
# Nearest to seven: zero, eight, four, three, five, two, six, one,
# Nearest to his: he, grandfather, awarded, beheaded, maesa, endemol, prionailurus, mountbatten,
# Nearest to pre: megaliths, originated, monolithic, strangely, daybreak, preclear, started, tiber,
# Nearest to event: ligases, click, functionalities, moment, scat, falls, events, heckel,
# Nearest to alternative: endosymbiosis, ways, hashem, amuck, totschlag, houteff, elephants, chokes,
# Nearest to recorded: homeward, hunchback, bacall, samantha, misty, singin, nu, bounding,
# Nearest to file: formatting, intrusive, relativism, files, revlon, wavelets, administrative, itunes,
# Nearest to grand: emphasise, indebtedness, segmentation, mali, marred, trygve, venlafaxine, sachsen,
# Nearest to professional: rookies, shackleton, named, stabs, taekwondo, cripple, diffracted, kibo,
# Nearest to placed: warrant, succession, fugues, hicks, unguarded, concealed, ilife, alkaloids,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0059 0.0382 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9696 0.0377 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9714 0.0379 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0070 0.0372 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0293 0.0376 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9639 0.0373 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9901 0.0373 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9922 0.0368 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9933 0.0376 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9814 0.0378 sec/batch
# Nearest to so: wagoner, refuting, impure, obtained, try, picket, start, calculi,
# Nearest to used: use, considered, sported, zirconia, midair, standardised, disproved, electrolytic,
# Nearest to between: forested, guaranteed, moines, level, uncollected, coloureds, and, carolla,
# Nearest to by: in, of, the, denominators, as, signal, ridley, june,
# Nearest to use: used, repeater, endings, though, deducted, evade, kaufman, outlining,
# Nearest to after: resulted, selhurst, before, danilo, potomac, afp, to, namely,
# Nearest to seven: zero, eight, three, four, five, two, six, one,
# Nearest to his: he, beheaded, grandfather, awarded, prionailurus, maesa, endemol, mountbatten,
# Nearest to pre: megaliths, monolithic, originated, strangely, daybreak, preclear, started, constructs,
# Nearest to event: ligases, click, moment, functionalities, events, scat, diffeomorphism, extremely,
# Nearest to alternative: endosymbiosis, ways, hashem, houteff, totschlag, chokes, amuck, disconcerting,
# Nearest to recorded: homeward, hunchback, samantha, bacall, singin, misty, nu, yesterday,
# Nearest to file: formatting, intrusive, files, itunes, wavelets, administrative, revlon, relativism,
# Nearest to grand: emphasise, indebtedness, segmentation, marred, mali, venlafaxine, sachsen, trygve,
# Nearest to professional: rookies, shackleton, named, cripple, taekwondo, stabs, kibo, gaining,
# Nearest to placed: hicks, unguarded, concealed, warrant, roof, fugues, succession, sit,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0125 0.0388 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9990 0.0375 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9889 0.0372 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9976 0.0376 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0052 0.0379 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0013 0.0375 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9720 0.0376 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9823 0.0368 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9812 0.0379 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0035 0.0379 sec/batch
# Nearest to so: wagoner, refuting, impure, obtained, calculi, start, picket, abstract,
# Nearest to used: use, considered, sported, standardised, midair, zirconia, disproved, electrolytic,
# Nearest to between: and, uncollected, forested, level, moines, coloureds, carolla, pubic,
# Nearest to by: in, of, the, as, various, june, denominators, and,
# Nearest to use: used, repeater, though, deducted, telephone, endings, evade, kaufman,
# Nearest to after: resulted, selhurst, danilo, before, to, returned, namely, reestablished,
# Nearest to seven: zero, eight, four, three, five, two, six, one,
# Nearest to his: he, grandfather, awarded, beheaded, prionailurus, endemol, tobe, mountbatten,
# Nearest to pre: megaliths, monolithic, originated, started, strangely, preclear, daybreak, faded,
# Nearest to event: ligases, click, events, functionalities, moment, christmas, scat, extremely,
# Nearest to alternative: endosymbiosis, hashem, ways, houteff, amuck, totschlag, pin, disconcerting,
# Nearest to recorded: homeward, hunchback, samantha, nu, singin, bacall, misty, crespigny,
# ...
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9397 0.0376 sec/batch
# Nearest to so: start, wagoner, know, relinquish, understand, calculi, tapu, try,
# Nearest to used: use, considered, sported, idiom, electrolytic, disambiguation, adopted, gloves,
# Nearest to between: and, a, the, both, with, than, into, pubic,
# Nearest to by: in, of, the, and, a, as, has, for,
# Nearest to use: used, evade, often, today, gemologists, telephone, repeater, early,
# Nearest to after: began, returned, with, to, had, before, namely, in,
# Nearest to seven: five, eight, three, zero, four, six, two, one,
# Nearest to his: he, him, father, prionailurus, grandfather, first, when, karlsson,
# Nearest to pre: megaliths, monolithic, only, started, colonizers, daybreak, columbian, strangely,
# Nearest to event: events, ligases, extinction, click, falls, moment, hutcheson, dates,
# Nearest to alternative: houteff, endosymbiosis, stp, debated, elephants, msc, linnaean, denote,
# Nearest to recorded: crespigny, misty, nu, singin, tempos, changeable, plume, homeward,
# Nearest to file: formatting, files, morissette, intrusive, administrative, itunes, wavelets, valiantly,
# Nearest to grand: emphasise, raced, prix, mali, sachsen, segmentation, venlafaxine, indebtedness,
# Nearest to professional: taekwondo, rookies, jenks, remedial, dojos, cripple, motocross, timeout,
# Nearest to placed: hicks, anus, disrupt, vesicle, concealed, gum, sit, breaker,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8271 0.0389 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8688 0.0367 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8603 0.0379 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8424 0.0367 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8530 0.0376 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8621 0.0375 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8508 0.0375 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8667 0.0374 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8668 0.0380 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8868 0.0377 sec/batch
# Nearest to so: refused, relinquish, know, talks, tapu, refuting, wagoner, zuben,
# Nearest to used: use, considered, sported, disproved, demigods, autodidacts, reduplication, idiom,
# Nearest to between: and, the, a, both, than, into, with, pubic,
# Nearest to by: of, the, in, and, a, as, for, has,
# Nearest to use: used, evade, modern, obscure, tippi, gemologists, today, repeater,
# Nearest to after: began, returned, namely, before, had, to, with, until,
# Nearest to seven: zero, five, eight, three, six, four, two, one,
# Nearest to his: he, him, grandfather, father, prionailurus, first, son, karlsson,
# Nearest to pre: started, megaliths, only, monolithic, columbian, colonizers, daybreak, preclear,
# Nearest to event: events, ligases, extinction, click, moment, dates, hutcheson, scat,
# Nearest to alternative: endosymbiosis, houteff, denote, linnaean, debated, extreme, elephants, ways,
# Nearest to recorded: crespigny, nu, tempos, yohannes, misty, changeable, homeward, plume,
# Nearest to file: formatting, files, itunes, morissette, intrusive, administrative, relativism, directories,
# Nearest to grand: emphasise, prix, raced, segmentation, sachsen, mali, venlafaxine, indebtedness,
# Nearest to professional: taekwondo, rookies, jenks, dojos, remedial, polytechnical, motocross, cripple,
# Nearest to placed: hicks, concealed, anus, disrupt, vesicle, gum, breaker, sit,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8702 0.0389 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8310 0.0377 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8245 0.0379 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8406 0.0371 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9351 0.0376 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8412 0.0378 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9661 0.0375 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8923 0.0375 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9103 0.0374 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8118 0.0374 sec/batch
# Nearest to so: refused, know, relinquish, zuben, wagoner, calculi, tapu, understand,
# Nearest to used: use, considered, sported, electrolytic, disproved, demigods, plutonium, gradius,
# Nearest to between: and, the, a, both, with, than, into, pubic,
# Nearest to by: the, of, in, and, a, as, has, with,
# Nearest to use: used, evade, today, repeater, modern, tippi, or, telephone,
# Nearest to after: began, to, returned, and, with, before, in, until,
# Nearest to seven: five, zero, eight, six, three, four, two, one,
# Nearest to his: he, him, grandfather, awarded, father, was, first, mba,
# Nearest to pre: started, megaliths, only, monolithic, columbian, daybreak, preclear, vivaldi,
# Nearest to event: events, extinction, ligases, click, moment, dates, fisherman, cena,
# Nearest to alternative: houteff, endosymbiosis, denote, ramones, debated, elephants, akan, extreme,
# Nearest to recorded: crespigny, misty, samantha, tempos, recording, yohannes, nu, singin,
# Nearest to file: formatting, files, itunes, morissette, relativism, intrusive, administrative, directories,
# Nearest to grand: emphasise, prix, raced, sachsen, mali, venlafaxine, segmentation, shogun,
# Nearest to professional: rookies, taekwondo, jenks, dojos, remedial, polytechnical, cripple, motocross,
# Nearest to placed: hicks, anus, concealed, disrupt, gum, vesicle, breaker, sit,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7882 0.0385 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8644 0.0369 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7837 0.0372 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8526 0.0375 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8223 0.0374 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8579 0.0378 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8769 0.0249 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8443 0.0379 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8361 0.0373 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8539 0.0375 sec/batch
# Nearest to so: refused, understand, tapu, relinquish, wagoner, know, zuben, babe,
# Nearest to used: use, considered, sported, electrolytic, demigods, practice, autodidacts, disproved,
# Nearest to between: and, both, a, with, the, than, into, pubic,
# Nearest to by: the, of, in, a, and, as, for, with,
# Nearest to use: used, evade, today, early, modern, gemologists, or, obscure,
# Nearest to after: began, to, returned, and, before, had, with, in,
# Nearest to seven: five, six, zero, three, eight, four, two, one,
# Nearest to his: he, him, grandfather, father, was, son, had, when,
# Nearest to pre: started, megaliths, monolithic, columbian, only, daybreak, colonizers, preclear,
# Nearest to event: events, ligases, extinction, click, fisherman, falls, moment, dates,
# Nearest to alternative: endosymbiosis, debated, houteff, ways, ramones, denote, extreme, frauds,
# Nearest to recorded: crespigny, nu, misty, singin, samantha, covered, recording, yohannes,
# Nearest to file: formatting, files, itunes, intrusive, morissette, relativism, directories, wavelets,
# Nearest to grand: emphasise, raced, prix, sachsen, mali, venlafaxine, segmentation, indebtedness,
# Nearest to professional: taekwondo, rookies, jenks, dojos, remedial, motocross, cripple, polytechnical,
# Nearest to placed: anus, hicks, concealed, disrupt, breaker, vesicle, gum, relatives,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8114 0.0386 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8488 0.0373 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7917 0.0372 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8529 0.0375 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8446 0.0376 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8328 0.0375 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8727 0.0374 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7358 0.0377 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8299 0.0378 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7798 0.0376 sec/batch
# Nearest to so: understand, tapu, relinquish, start, know, wagoner, try, peroxy,
# Nearest to used: use, considered, idiom, adopted, electrolytic, demigods, ocs, is,
# Nearest to between: and, both, a, the, with, into, than, pubic,
# Nearest to by: in, of, the, and, a, as, with, for,
# Nearest to use: used, evade, or, today, stimulants, naming, tippi, often,
# Nearest to after: began, returned, with, namely, to, until, had, before,
# Nearest to seven: five, six, zero, three, four, eight, two, one,
# Nearest to his: he, him, grandfather, father, son, first, awarded, when,
# Nearest to pre: started, columbian, megaliths, monolithic, only, colonizers, weaponry, daybreak,
# Nearest to event: events, ligases, extinction, click, dates, falls, cena, potentials,
# Nearest to alternative: houteff, endosymbiosis, debated, stp, ways, edmondson, romanizations, akan,
# Nearest to recorded: crespigny, misty, singin, about, roughly, wiped, yohannes, nu,
# Nearest to file: formatting, files, relativism, itunes, morissette, intrusive, administrative, wavelets,
# Nearest to grand: emphasise, raced, prix, mali, sachsen, segmentation, indebtedness, venlafaxine,
# Nearest to professional: taekwondo, rookies, jenks, remedial, dojos, motocross, cripple, deflate,
# Nearest to placed: concealed, hicks, anus, disrupt, gum, vesicle, relatives, breaker,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7699 0.0389 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8525 0.0379 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8511 0.0371 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8238 0.0374 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8412 0.0373 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9048 0.0375 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8448 0.0372 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8121 0.0376 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8552 0.0379 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8213 0.0380 sec/batch
# Nearest to so: understand, tapu, relinquish, know, calculi, refused, start, particulars,
# Nearest to used: use, considered, distributivity, was, idiom, electrolytic, ocs, adopted,
# Nearest to between: and, both, the, a, with, into, than, pubic,
# Nearest to by: the, of, in, a, and, as, for, has,
# Nearest to use: used, today, evade, or, often, though, early, stimulants,
# Nearest to after: began, returned, namely, had, to, until, when, with,
# Nearest to seven: five, zero, three, six, eight, four, two, one,
# Nearest to his: he, him, father, grandfather, first, when, son, career,
# Nearest to pre: megaliths, started, only, columbian, monolithic, colonizers, daybreak, weaponry,
# Nearest to event: events, ligases, extinction, click, falls, moment, dates, macrostate,
# Nearest to alternative: endosymbiosis, houteff, debated, ways, extreme, denote, stp, arnold,
# Nearest to recorded: recording, crespigny, nu, tempos, cddb, misty, yohannes, singin,
# Nearest to file: formatting, files, relativism, intrusive, itunes, wavelets, morissette, administrative,
# Nearest to grand: emphasise, prix, raced, mali, sachsen, venlafaxine, segmentation, windsor,
# Nearest to professional: taekwondo, rookies, jenks, remedial, motocross, dojos, gifted, cripple,
# Nearest to placed: hicks, concealed, vesicle, anus, gum, breaker, disrupt, sit,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8424 0.0390 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8453 0.0379 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8211 0.0375 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8206 0.0372 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8555 0.0371 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8622 0.0376 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8580 0.0375 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8391 0.0380 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8195 0.0379 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8142 0.0379 sec/batch
# Nearest to so: relinquish, tapu, know, refused, understand, that, holder, calculi,
# Nearest to used: use, considered, was, for, a, of, is, by,
# Nearest to between: and, the, a, both, with, than, into, in,
# Nearest to by: the, a, of, in, and, as, for, with,
# Nearest to use: used, or, evade, today, early, modern, for, stimulants,
# Nearest to after: began, with, to, and, until, namely, returned, in,
# Nearest to seven: five, zero, six, three, four, eight, two, one,
# Nearest to his: he, him, grandfather, son, father, rainstorm, beheaded, first,
# Nearest to pre: started, megaliths, columbian, monolithic, only, colonizers, preclear, faded,
# Nearest to event: events, extinction, ligases, click, dates, fisherman, cena, falls,
# Nearest to alternative: endosymbiosis, houteff, debated, ways, centrifuge, romanizations, denote, msc,
# Nearest to recorded: crespigny, nu, recording, yohannes, tempos, roughly, misty, cddb,
# Nearest to file: files, formatting, relativism, itunes, intrusive, wavelets, administrative, morissette,
# Nearest to grand: emphasise, prix, raced, sachsen, mali, segmentation, venlafaxine, indebtedness,
# Nearest to professional: taekwondo, rookies, jenks, dojos, remedial, motocross, cripple, christos,
# Nearest to placed: concealed, hicks, disrupt, anus, gum, vesicle, breaker, sit,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8789 0.0391 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8386 0.0376 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9354 0.0378 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9111 0.0379 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9108 0.0380 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8327 0.0378 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7675 0.0370 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8351 0.0377 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7475 0.0376 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8390 0.0380 sec/batch
# Nearest to so: relinquish, know, tapu, understand, calculi, start, refused, that,
# Nearest to used: use, considered, connotations, demigods, adopted, electrolytic, disproved, disambiguation,
# Nearest to between: and, the, both, a, with, in, than, into,
# Nearest to by: the, of, in, a, and, as, for, with,
# Nearest to use: used, today, or, evade, early, modern, for, often,
# Nearest to after: began, returned, until, to, had, when, ceased, and,
# Nearest to seven: five, eight, six, zero, four, three, two, one,
# Nearest to his: he, him, grandfather, father, masterful, gravestone, rainstorm, first,
# Nearest to pre: started, columbian, megaliths, monolithic, only, preclear, colonizers, weaponry,
# Nearest to event: events, ligases, extinction, click, fisherman, cena, scat, moment,
# Nearest to alternative: endosymbiosis, houteff, colecovision, romanizations, ways, debated, ramones, akan,
# Nearest to recorded: crespigny, recording, singin, tempos, misty, nu, record, cddb,
# Nearest to file: files, formatting, relativism, itunes, wavelets, morissette, intrusive, administrative,
# Nearest to grand: emphasise, prix, raced, sachsen, mali, venlafaxine, windsor, modena,
# Nearest to professional: taekwondo, rookies, jenks, dojos, motocross, remedial, christos, cripple,
# Nearest to placed: concealed, hicks, anus, disrupt, breaker, gum, renumbered, vesicle,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8642 0.0388 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8299 0.0378 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
